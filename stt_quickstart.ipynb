# %% [markdown]
# # Fast LJSpeech STT
#
# This notebook is a thin wrapper around the script-based project. The codebase itself lives in the `.py` files so training and inference stay clean and reproducible.

# %% [markdown]
# ## 1. Install requirements

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 2. Expected LJSpeech layout
#
# ```text
# data/LJSpeech-1.1/
# ├── metadata.csv
# └── wavs/
#     ├── LJ001-0001.wav
#     └── ...
# ```

# %% [markdown]
# ## 3. Tiny debug run

# %%
# !python train.py --config configs/tiny_debug.yaml --dataset-root data/LJSpeech-1.1

# %% [markdown]
# ## 4. Fast 1000-sample run

# %%
# !python train.py --config configs/ljspeech_fast.yaml --dataset-root data/LJSpeech-1.1

# %% [markdown]
# ## 5. One-file inference

# %%
# !python infer.py --checkpoint runs/ljspeech_fast/best.pt --audio path/to/file.wav
